# %% [markdown]
# # Calculate Distances of Decomposition Components (02/09)
# ## 1. Observing and selecting 6 examples

# %%
import math
import pandas as pd
import pywt
import numpy as np
from matplotlib.pyplot import figure
from scipy import fftpack
from scipy import signal
import matplotlib.pyplot as plt
from mat4py import loadmat
import os
import scipy.io as sio
from sklearn.preprocessing import StandardScaler
from itertools import combinations, chain

# %%
ex1=pd.read_csv(r"C:\Ninapro\pieces\S1_C3_G10_T3.csv")
ex2=pd.read_csv(r"C:\Ninapro\pieces\S6_C4_G10_T3.csv")
ex3=pd.read_csv(r"C:\Ninapro\pieces\S8_C4_G3_T2.csv")
ex4=pd.read_csv(r"C:\Ninapro\pieces\S4_C2_G7_T3.csv")
ex5=pd.read_csv(r"C:\Ninapro\pieces\S3_C3_G5_T4.csv")
ex6=pd.read_csv(r"C:\Ninapro\pieces\S10_C8_G16_T5.csv")

# %%
figure(figsize=(40,5))
plt.plot(ex1)
plt.show()
figure(figsize=(40,5))
plt.plot(ex2)
plt.show()
figure(figsize=(40,5))
plt.plot(ex3)
plt.show()
figure(figsize=(40,5))
plt.plot(ex4)
plt.show()
figure(figsize=(40,5))
plt.plot(ex5)
plt.show()
figure(figsize=(40,5))
plt.plot(ex6)
plt.show()

# %% [markdown]
# ## 2. Implement the calucation of distances of components in MATLAB
# Including ewt and efd results. The decomposition results has been saved in previous work.

# %% [markdown]
# %MATLAB CODE FOR IS_DISTANCE
#
# ewt_ex1 = readtable('C:\Ninapro\pieces_ewt\S1_C3_G10_T3.csv');
# ewt_ex1_1 = table2array(ewt_ex1(:,1)).';
# ewt_ex1_2 = table2array(ewt_ex1(:,2)).';
# ewt_ex1_3 = table2array(ewt_ex1(:,3)).';
# ewt_ex1_4 = table2array(ewt_ex1(:,4)).';
# ewt_ex1_5 = table2array(ewt_ex1(:,5)).';
# ewt_ex1_12=v_distispf(ewt_ex1_1,ewt_ex1_2);
# ewt_ex1_13=v_distispf(ewt_ex1_1,ewt_ex1_3);
# ewt_ex1_14=v_distispf(ewt_ex1_1,ewt_ex1_4);
# ewt_ex1_15=v_distispf(ewt_ex1_1,ewt_ex1_5);
# ewt_ex1_23=v_distispf(ewt_ex1_2,ewt_ex1_3);
# ewt_ex1_24=v_distispf(ewt_ex1_2,ewt_ex1_4);
# ewt_ex1_25=v_distispf(ewt_ex1_2,ewt_ex1_5);
# ewt_ex1_34=v_distispf(ewt_ex1_3,ewt_ex1_4);
# ewt_ex1_35=v_distispf(ewt_ex1_3,ewt_ex1_5);
# ewt_ex1_45=v_distispf(ewt_ex1_4,ewt_ex1_5);
#
# ewt_ex2 = readtable('C:\Ninapro\pieces_ewt\S6_C4_G10_T3.csv');
# ewt_ex2_1 = table2array(ewt_ex2(:,1)).';
# ewt_ex2_2 = table2array(ewt_ex2(:,2)).';
# ewt_ex2_3 = table2array(ewt_ex2(:,3)).';
# ewt_ex2_4 = table2array(ewt_ex2(:,4)).';
# ewt_ex2_5 = table2array(ewt_ex2(:,5)).';
# ewt_ex2_12=v_distispf(ewt_ex2_1,ewt_ex2_2);
# ewt_ex2_13=v_distispf(ewt_ex2_1,ewt_ex2_3);
# ewt_ex2_14=v_distispf(ewt_ex2_1,ewt_ex2_4);
# ewt_ex2_15=v_distispf(ewt_ex2_1,ewt_ex2_5);
# ewt_ex2_23=v_distispf(ewt_ex2_2,ewt_ex2_3);
# ewt_ex2_24=v_distispf(ewt_ex2_2,ewt_ex2_4);
# ewt_ex2_25=v_distispf(ewt_ex2_2,ewt_ex2_5);
# ewt_ex2_34=v_distispf(ewt_ex2_3,ewt_ex2_4);
# ewt_ex2_35=v_distispf(ewt_ex2_3,ewt_ex2_5);
# ewt_ex2_45=v_distispf(ewt_ex2_4,ewt_ex2_5);
#
# ewt_ex3 = readtable('C:\Ninapro\pieces_ewt\S8_C4_G3_T2.csv');
# ewt_ex3_1 = table2array(ewt_ex3(:,1)).';
# ewt_ex3_2 = table2array(ewt_ex3(:,2)).';
# ewt_ex3_3 = table2array(ewt_ex3(:,3)).';
# ewt_ex3_4 = table2array(ewt_ex3(:,4)).';
# ewt_ex3_5 = table2array(ewt_ex3(:,5)).';
# ewt_ex3_12=v_distispf(ewt_ex3_1,ewt_ex3_2);
# ewt_ex3_13=v_distispf(ewt_ex3_1,ewt_ex3_3);
# ewt_ex3_14=v_distispf(ewt_ex3_1,ewt_ex3_4);
# ewt_ex3_15=v_distispf(ewt_ex3_1,ewt_ex3_5);
# ewt_ex3_23=v_distispf(ewt_ex3_2,ewt_ex3_3);
# ewt_ex3_24=v_distispf(ewt_ex3_2,ewt_ex3_4);
# ewt_ex3_25=v_distispf(ewt_ex3_2,ewt_ex3_5);
# ewt_ex3_34=v_distispf(ewt_ex3_3,ewt_ex3_4);
# ewt_ex3_35=v_distispf(ewt_ex3_3,ewt_ex3_5);
# ewt_ex3_45=v_distispf(ewt_ex3_4,ewt_ex3_5);
#
#
# ewt_ex4 = readtable('C:\Ninapro\pieces_ewt\S4_C2_G7_T3.csv');
# ewt_ex4_1 = table2array(ewt_ex4(:,1)).';
# ewt_ex4_2 = table2array(ewt_ex4(:,2)).';
# ewt_ex4_3 = table2array(ewt_ex4(:,3)).';
# ewt_ex4_4 = table2array(ewt_ex4(:,4)).';
# ewt_ex4_5 = table2array(ewt_ex4(:,5)).';
# ewt_ex4_12=v_distispf(ewt_ex4_1,ewt_ex4_2);
# ewt_ex4_13=v_distispf(ewt_ex4_1,ewt_ex4_3);
# ewt_ex4_14=v_distispf(ewt_ex4_1,ewt_ex4_4);
# ewt_ex4_15=v_distispf(ewt_ex4_1,ewt_ex4_5);
# ewt_ex4_23=v_distispf(ewt_ex4_2,ewt_ex4_3);
# ewt_ex4_24=v_distispf(ewt_ex4_2,ewt_ex4_4);
# ewt_ex4_25=v_distispf(ewt_ex4_2,ewt_ex4_5);
# ewt_ex4_34=v_distispf(ewt_ex4_3,ewt_ex4_4);
# ewt_ex4_35=v_distispf(ewt_ex4_3,ewt_ex4_5);
# ewt_ex4_45=v_distispf(ewt_ex4_4,ewt_ex4_5);
#
#
# ewt_ex5 = readtable('C:\Ninapro\pieces_ewt\S3_C3_G5_T4.csv');
# ewt_ex5_1 = table2array(ewt_ex5(:,1)).';
# ewt_ex5_2 = table2array(ewt_ex5(:,2)).';
# ewt_ex5_3 = table2array(ewt_ex5(:,3)).';
# ewt_ex5_4 = table2array(ewt_ex5(:,4)).';
# ewt_ex5_5 = table2array(ewt_ex5(:,5)).';
# ewt_ex5_12=v_distispf(ewt_ex5_1,ewt_ex5_2);
# ewt_ex5_13=v_distispf(ewt_ex5_1,ewt_ex5_3);
# ewt_ex5_14=v_distispf(ewt_ex5_1,ewt_ex5_4);
# ewt_ex5_15=v_distispf(ewt_ex5_1,ewt_ex5_5);
# ewt_ex5_23=v_distispf(ewt_ex5_2,ewt_ex5_3);
# ewt_ex5_24=v_distispf(ewt_ex5_2,ewt_ex5_4);
# ewt_ex5_25=v_distispf(ewt_ex5_2,ewt_ex5_5);
# ewt_ex5_34=v_distispf(ewt_ex5_3,ewt_ex5_4);
# ewt_ex5_35=v_distispf(ewt_ex5_3,ewt_ex5_5);
# ewt_ex5_45=v_distispf(ewt_ex5_4,ewt_ex5_5);
#
#
# ewt_ex6 = readtable('C:\Ninapro\pieces_ewt\S10_C8_G16_T5.csv');
# ewt_ex6_1 = table2array(ewt_ex6(:,1)).';
# ewt_ex6_2 = table2array(ewt_ex6(:,2)).';
# ewt_ex6_3 = table2array(ewt_ex6(:,3)).';
# ewt_ex6_4 = table2array(ewt_ex6(:,4)).';
# ewt_ex6_5 = table2array(ewt_ex6(:,5)).';
# ewt_ex6_12=v_distispf(ewt_ex6_1,ewt_ex6_2);
# ewt_ex6_13=v_distispf(ewt_ex6_1,ewt_ex6_3);
# ewt_ex6_14=v_distispf(ewt_ex6_1,ewt_ex6_4);
# ewt_ex6_15=v_distispf(ewt_ex6_1,ewt_ex6_5);
# ewt_ex6_23=v_distispf(ewt_ex6_2,ewt_ex6_3);
# ewt_ex6_24=v_distispf(ewt_ex6_2,ewt_ex6_4);
# ewt_ex6_25=v_distispf(ewt_ex6_2,ewt_ex6_5);
# ewt_ex6_34=v_distispf(ewt_ex6_3,ewt_ex6_4);
# ewt_ex6_35=v_distispf(ewt_ex6_3,ewt_ex6_5);
# ewt_ex6_45=v_distispf(ewt_ex6_4,ewt_ex6_5);
#
#
# efd_ex1 = readtable('C:\Ninapro\pieces_efd\S1_C3_G10_T3.csv');
# efd_ex1_1 = table2array(efd_ex1(:,1)).';
# efd_ex1_2 = table2array(efd_ex1(:,2)).';
# efd_ex1_3 = table2array(efd_ex1(:,3)).';
# efd_ex1_4 = table2array(efd_ex1(:,4)).';
# efd_ex1_5 = table2array(efd_ex1(:,5)).';
# efd_ex1_12=v_distispf(efd_ex1_1,efd_ex1_2);
# efd_ex1_13=v_distispf(efd_ex1_1,efd_ex1_3);
# efd_ex1_14=v_distispf(efd_ex1_1,efd_ex1_4);
# efd_ex1_15=v_distispf(efd_ex1_1,efd_ex1_5);
# efd_ex1_23=v_distispf(efd_ex1_2,efd_ex1_3);
# efd_ex1_24=v_distispf(efd_ex1_2,efd_ex1_4);
# efd_ex1_25=v_distispf(efd_ex1_2,efd_ex1_5);
# efd_ex1_34=v_distispf(efd_ex1_3,efd_ex1_4);
# efd_ex1_35=v_distispf(efd_ex1_3,efd_ex1_5);
# efd_ex1_45=v_distispf(efd_ex1_4,efd_ex1_5);
#
# efd_ex2 = readtable('C:\Ninapro\pieces_efd\S6_C4_G10_T3.csv');
# efd_ex2_1 = table2array(efd_ex2(:,1)).';
# efd_ex2_2 = table2array(efd_ex2(:,2)).';
# efd_ex2_3 = table2array(efd_ex2(:,3)).';
# efd_ex2_4 = table2array(efd_ex2(:,4)).';
# efd_ex2_5 = table2array(efd_ex2(:,5)).';
# efd_ex2_12=v_distispf(efd_ex2_1,efd_ex2_2);
# efd_ex2_13=v_distispf(efd_ex2_1,efd_ex2_3);
# efd_ex2_14=v_distispf(efd_ex2_1,efd_ex2_4);
# efd_ex2_15=v_distispf(efd_ex2_1,efd_ex2_5);
# efd_ex2_23=v_distispf(efd_ex2_2,efd_ex2_3);
# efd_ex2_24=v_distispf(efd_ex2_2,efd_ex2_4);
# efd_ex2_25=v_distispf(efd_ex2_2,efd_ex2_5);
# efd_ex2_34=v_distispf(efd_ex2_3,efd_ex2_4);
# efd_ex2_35=v_distispf(efd_ex2_3,efd_ex2_5);
# efd_ex2_45=v_distispf(efd_ex2_4,efd_ex2_5);
#
# efd_ex3 = readtable('C:\Ninapro\pieces_efd\S8_C4_G3_T2.csv');
# efd_ex3_1 = table2array(efd_ex3(:,1)).';
# efd_ex3_2 = table2array(efd_ex3(:,2)).';
# efd_ex3_3 = table2array(efd_ex3(:,3)).';
# efd_ex3_4 = table2array(efd_ex3(:,4)).';
# efd_ex3_5 = table2array(efd_ex3(:,5)).';
# efd_ex3_12=v_distispf(efd_ex3_1,efd_ex3_2);
# efd_ex3_13=v_distispf(efd_ex3_1,efd_ex3_3);
# efd_ex3_14=v_distispf(efd_ex3_1,efd_ex3_4);
# efd_ex3_15=v_distispf(efd_ex3_1,efd_ex3_5);
# efd_ex3_23=v_distispf(efd_ex3_2,efd_ex3_3);
# efd_ex3_24=v_distispf(efd_ex3_2,efd_ex3_4);
# efd_ex3_25=v_distispf(efd_ex3_2,efd_ex3_5);
# efd_ex3_34=v_distispf(efd_ex3_3,efd_ex3_4);
# efd_ex3_35=v_distispf(efd_ex3_3,efd_ex3_5);
# efd_ex3_45=v_distispf(efd_ex3_4,efd_ex3_5);
#
#
# efd_ex4 = readtable('C:\Ninapro\pieces_efd\S4_C2_G7_T3.csv');
# efd_ex4_1 = table2array(efd_ex4(:,1)).';
# efd_ex4_2 = table2array(efd_ex4(:,2)).';
# efd_ex4_3 = table2array(efd_ex4(:,3)).';
# efd_ex4_4 = table2array(efd_ex4(:,4)).';
# efd_ex4_5 = table2array(efd_ex4(:,5)).';
# efd_ex4_12=v_distispf(efd_ex4_1,efd_ex4_2);
# efd_ex4_13=v_distispf(efd_ex4_1,efd_ex4_3);
# efd_ex4_14=v_distispf(efd_ex4_1,efd_ex4_4);
# efd_ex4_15=v_distispf(efd_ex4_1,efd_ex4_5);
# efd_ex4_23=v_distispf(efd_ex4_2,efd_ex4_3);
# efd_ex4_24=v_distispf(efd_ex4_2,efd_ex4_4);
# efd_ex4_25=v_distispf(efd_ex4_2,efd_ex4_5);
# efd_ex4_34=v_distispf(efd_ex4_3,efd_ex4_4);
# efd_ex4_35=v_distispf(efd_ex4_3,efd_ex4_5);
# efd_ex4_45=v_distispf(efd_ex4_4,efd_ex4_5);
#
#
# efd_ex5 = readtable('C:\Ninapro\pieces_efd\S3_C3_G5_T4.csv');
# efd_ex5_1 = table2array(efd_ex5(:,1)).';
# efd_ex5_2 = table2array(efd_ex5(:,2)).';
# efd_ex5_3 = table2array(efd_ex5(:,3)).';
# efd_ex5_4 = table2array(efd_ex5(:,4)).';
# efd_ex5_5 = table2array(efd_ex5(:,5)).';
# efd_ex5_12=v_distispf(efd_ex5_1,efd_ex5_2);
# efd_ex5_13=v_distispf(efd_ex5_1,efd_ex5_3);
# efd_ex5_14=v_distispf(efd_ex5_1,efd_ex5_4);
# efd_ex5_15=v_distispf(efd_ex5_1,efd_ex5_5);
# efd_ex5_23=v_distispf(efd_ex5_2,efd_ex5_3);
# efd_ex5_24=v_distispf(efd_ex5_2,efd_ex5_4);
# efd_ex5_25=v_distispf(efd_ex5_2,efd_ex5_5);
# efd_ex5_34=v_distispf(efd_ex5_3,efd_ex5_4);
# efd_ex5_35=v_distispf(efd_ex5_3,efd_ex5_5);
# efd_ex5_45=v_distispf(efd_ex5_4,efd_ex5_5);
#
#
# efd_ex6 = readtable('C:\Ninapro\pieces_efd\S10_C8_G16_T5.csv');
# efd_ex6_1 = table2array(efd_ex6(:,1)).';
# efd_ex6_2 = table2array(efd_ex6(:,2)).';
# efd_ex6_3 = table2array(efd_ex6(:,3)).';
# efd_ex6_4 = table2array(efd_ex6(:,4)).';
# efd_ex6_5 = table2array(efd_ex6(:,5)).';
# efd_ex6_12=v_distispf(efd_ex6_1,efd_ex6_2);
# efd_ex6_13=v_distispf(efd_ex6_1,efd_ex6_3);
# efd_ex6_14=v_distispf(efd_ex6_1,efd_ex6_4);
# efd_ex6_15=v_distispf(efd_ex6_1,efd_ex6_5);
# efd_ex6_23=v_distispf(efd_ex6_2,efd_ex6_3);
# efd_ex6_24=v_distispf(efd_ex6_2,efd_ex6_4);
# efd_ex6_25=v_distispf(efd_ex6_2,efd_ex6_5);
# efd_ex6_34=v_distispf(efd_ex6_3,efd_ex6_4);
# efd_ex6_35=v_distispf(efd_ex6_3,efd_ex6_5);
# efd_ex6_45=v_distispf(efd_ex6_4,efd_ex6_5);

# %% [markdown]
# ## 3. Save all the distances from Section 2 in dataframe
# After converting from .mat to .csv, some manipulation was done in excel.

# %%
from scipy.io import loadmat
import pandas as pd
mat = loadmat(r'C:\Users\16468\Desktop\Pancholi\matlab_is_dist.mat')

# %%
#mat to csv
resultList = list(mat.keys())
vals = list(mat.values())
df = pd.DataFrame({'name':resultList,'value':vals})
df.to_csv(r'C:\Users\16468\Desktop\Pancholi\matlab_is_dist.csv')

# %%
df_fin=pd.read_csv(r'C:\Users\16468\Desktop\Pancholi\matlab_is_distance.csv')

# %%
df_fin
# Out:
#            name method example  2_compo      real         j
# 0    efd_ex1_12    efd     ex1       12  1.735813 -1.628512
# 1    efd_ex1_13    efd     ex1       13  0.841611 -1.593015
# 2    efd_ex1_14    efd     ex1       14 -3.379527 -1.594343
# 3    efd_ex1_15    efd     ex1       15  0.378390 -1.595759
# 4    efd_ex1_23    efd     ex1       23 -0.249652 -1.583720
# ..          ...    ...     ...      ...       ...       ...
# 115  ewt_ex6_24    ewt     ex6       24 -0.826395 -1.569999
# 116  ewt_ex6_25    ewt     ex6       25 -0.060804 -1.593662
# 117  ewt_ex6_34    ewt     ex6       34 -0.360317 -1.559984
# 118  ewt_ex6_35    ewt     ex6       35  0.427303 -1.562909
# 119  ewt_ex6_45    ewt     ex6       45 -0.079019 -1.585420
#
# [120 rows x 6 columns]

# %% [markdown]
# ## 4. Scatter plots for each examples

# %%
# separate each example signal
df_ex1= df_fin[df_fin['example']=='ex1']
df_ex2= df_fin[df_fin['example']=='ex2']
df_ex3= df_fin[df_fin['example']=='ex3']
df_ex4= df_fin[df_fin['example']=='ex4']
df_ex5= df_fin[df_fin['example']=='ex5']
df_ex6= df_fin[df_fin['example']=='ex6']

# %%
df_ex1.head()
# Out:
#          name method example  2_compo      real         j
# 0  efd_ex1_12    efd     ex1       12  1.735813 -1.628512
# 1  efd_ex1_13    efd     ex1       13  0.841611 -1.593015
# 2  efd_ex1_14    efd     ex1       14 -3.379527 -1.594343
# 3  efd_ex1_15    efd     ex1       15  0.378390 -1.595759
# 4  efd_ex1_23    efd     ex1       23 -0.249652 -1.583720

# %%
df_ex1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 69
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     20 non-null     object
#  1   method   20 non-null     object
#  2   example  20 non-null     object
#  3   2_compo  20 non-null     int64
#  4   real     20 non-null     float64
#  5   j        20 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.1+ KB

# %%
plt.style.use('ggplot')

# %% [markdown]
# The plots will compare the components IS-distances for EWT and EFD. The legends are EWT and EFD. Each plot shows the results of each example.

# %%
# example 1
plt.scatter(df_ex1[df_ex1['method']=='ewt']['real'], df_ex1[df_ex1['method']=='ewt']['j'], 
            s=df_ex1[df_ex1['method']=='ewt']['2_compo']*2, c='b', marker="s", label='EWT',alpha=0.6)
plt.scatter(df_ex1[df_ex1['method']=='efd']['real'], df_ex1[df_ex1['method']=='efd']['j'], 
            s=df_ex1[df_ex1['method']=='ewt']['2_compo']*2, c='r', marker="o", label='EFD', alpha=0.6)
plt.legend(loc='upper left')
plt.xlabel('Real') 
plt.ylabel('Imagine') 
plt.title("Example Signal 1")

plt.show()

# %%
# example 2
plt.scatter(df_ex2[df_ex2['method']=='ewt']['real'], df_ex2[df_ex2['method']=='ewt']['j'], 
            s=df_ex2[df_ex2['method']=='ewt']['2_compo']*2, c='b', marker="s", label='EWT',alpha=0.6)
plt.scatter(df_ex2[df_ex2['method']=='efd']['real'], df_ex2[df_ex2['method']=='efd']['j'], 
            s=df_ex2[df_ex2['method']=='ewt']['2_compo']*2, c='r', marker="o", label='EFD', alpha=0.6)
plt.legend(loc='upper left')
plt.xlabel('Real') 
plt.ylabel('Imagine') 
plt.title("Example Signal 2")

plt.show()

# %%
# example 3
plt.scatter(df_ex3[df_ex3['method']=='ewt']['real'], df_ex3[df_ex3['method']=='ewt']['j'], 
            s=df_ex3[df_ex3['method']=='ewt']['2_compo']*2, c='b', marker="s", label='EWT',alpha=0.6)
plt.scatter(df_ex3[df_ex3['method']=='efd']['real'], df_ex3[df_ex3['method']=='efd']['j'], 
            s=df_ex3[df_ex3['method']=='ewt']['2_compo']*2, c='r', marker="o", label='EFD', alpha=0.6)
plt.legend(loc='upper left')
plt.xlabel('Real') 
plt.ylabel('Imagine') 
plt.title("Example Signal 3")

plt.show()

# %%
# example 4
plt.scatter(df_ex4[df_ex4['method']=='ewt']['real'], df_ex4[df_ex4['method']=='ewt']['j'], 
            s=df_ex3[df_ex3['method']=='ewt']['2_compo']*2, c='b', marker="s", label='EWT',alpha=0.6)
plt.scatter(df_ex4[df_ex4['method']=='efd']['real'], df_ex4[df_ex4['method']=='efd']['j'], 
            s=df_ex4[df_ex4['method']=='ewt']['2_compo']*2, c='r', marker="o", label='EFD', alpha=0.6)
plt.legend(loc='upper left')
plt.xlabel('Real') 
plt.ylabel('Imagine') 
plt.title("Example Signal 4")

plt.show()

# %%
# example 5
plt.scatter(df_ex5[df_ex5['method']=='ewt']['real'], df_ex5[df_ex5['method']=='ewt']['j'], 
            s=df_ex3[df_ex3['method']=='ewt']['2_compo']*2, c='b', marker="s", label='EWT',alpha=0.6)
plt.scatter(df_ex5[df_ex5['method']=='efd']['real'], df_ex5[df_ex5['method']=='efd']['j'], 
            s=df_ex5[df_ex5['method']=='ewt']['2_compo']*2, c='r', marker="o", label='EFD', alpha=0.6)
plt.legend(loc='upper left')
plt.xlabel('Real') 
plt.ylabel('Imagine') 
plt.title("Example Signal 5")

plt.show()

# %%
# example 6
plt.scatter(df_ex6[df_ex6['method']=='ewt']['real'], df_ex6[df_ex6['method']=='ewt']['j'], 
            s=df_ex3[df_ex3['method']=='ewt']['2_compo']*2, c='b', marker="s", label='EWT',alpha=0.6)
plt.scatter(df_ex6[df_ex6['method']=='efd']['real'], df_ex6[df_ex6['method']=='efd']['j'], 
            s=df_ex6[df_ex6['method']=='ewt']['2_compo']*2, c='r', marker="o", label='EFD', alpha=0.6)
plt.legend(loc='upper left')
plt.xlabel('Real') 
plt.ylabel('Imagine') 
plt.title("Example Signal 6")

plt.show()

# %% [markdown]
# The scatter size indicates the same pair of components distances generated by EWT and EFD. For example, the similar/same size red dot and blue square means the same pair of components distances, such as comp4 and comp5, the largest red dot is the distance of 4 and 5 for EWT, while the largest blue dot is the distance of 4 and 5 for EFD.

# %% [markdown]
# ## 5. Re-sample the signal points with the same channel

# %%
ex1=pd.read_csv(r"C:\Ninapro\pieces\S1_C3_G1_T3.csv")
ex2=pd.read_csv(r"C:\Ninapro\pieces\S6_C3_G10_T2.csv")
ex3=pd.read_csv(r"C:\Ninapro\pieces\S8_C3_G3_T2.csv")
ex4=pd.read_csv(r"C:\Ninapro\pieces\S4_C3_G7_T3.csv")
ex5=pd.read_csv(r"C:\Ninapro\pieces\S3_C3_G5_T4.csv")
ex6=pd.read_csv(r"C:\Ninapro\pieces\S10_C3_G16_T5.csv")

# %%
figure(figsize=(40,5))
plt.plot(ex1)
plt.show()
figure(figsize=(40,5))
plt.plot(ex2)
plt.show()
figure(figsize=(40,5))
plt.plot(ex3)
plt.show()
figure(figsize=(40,5))
plt.plot(ex4)
plt.show()
figure(figsize=(40,5))
plt.plot(ex5)
plt.show()
figure(figsize=(40,5))
plt.plot(ex6)
plt.show()

# %% [markdown]
# ## 6. MATLAB Implementation of IS-Distance
# %for these items, each components will add 0.001 to be positive.
#
# %MATLAB CODE FOR IS_DISTANCE
#
# ewt_ex1 = readtable('C:\Ninapro\pieces_is\S1_C3_G1_T3_EWT.csv');
# ewt_ex1_1 = table2array(ewt_ex1(:,1)).';
# ewt_ex1_2 = table2array(ewt_ex1(:,2)).';
# ewt_ex1_3 = table2array(ewt_ex1(:,3)).';
# ewt_ex1_4 = table2array(ewt_ex1(:,4)).';
# ewt_ex1_5 = table2array(ewt_ex1(:,5)).';
# ewt_ex1_12=v_distispf(ewt_ex1_1+0.001,ewt_ex1_2+0.001);
# ewt_ex1_13=v_distispf(ewt_ex1_1+0.001,ewt_ex1_3+0.001);
# ewt_ex1_14=v_distispf(ewt_ex1_1+0.001,ewt_ex1_4+0.001);
# ewt_ex1_15=v_distispf(ewt_ex1_1+0.001,ewt_ex1_5+0.001);
# ewt_ex1_23=v_distispf(ewt_ex1_2+0.001,ewt_ex1_3+0.001);
# ewt_ex1_24=v_distispf(ewt_ex1_2+0.001,ewt_ex1_4+0.001);
# ewt_ex1_25=v_distispf(ewt_ex1_2+0.001,ewt_ex1_5+0.001);
# ewt_ex1_34=v_distispf(ewt_ex1_3+0.001,ewt_ex1_4+0.001);
# ewt_ex1_35=v_distispf(ewt_ex1_3+0.001,ewt_ex1_5+0.001);
# ewt_ex1_45=v_distispf(ewt_ex1_4+0.001,ewt_ex1_5+0.001);
#
# ewt_ex2 = readtable('C:\Ninapro\pieces_is\S6_C3_G10_T2_EWT.csv');
# ewt_ex2_1 = table2array(ewt_ex2(:,1)).';
# ewt_ex2_2 = table2array(ewt_ex2(:,2)).';
# ewt_ex2_3 = table2array(ewt_ex2(:,3)).';
# ewt_ex2_4 = table2array(ewt_ex2(:,4)).';
# ewt_ex2_5 = table2array(ewt_ex2(:,5)).';
# ewt_ex2_12=v_distispf(ewt_ex2_1+0.001,ewt_ex2_2+0.001);
# ewt_ex2_13=v_distispf(ewt_ex2_1+0.001,ewt_ex2_3+0.001);
# ewt_ex2_14=v_distispf(ewt_ex2_1+0.001,ewt_ex2_4+0.001);
# ewt_ex2_15=v_distispf(ewt_ex2_1+0.001,ewt_ex2_5+0.001);
# ewt_ex2_23=v_distispf(ewt_ex2_2+0.001,ewt_ex2_3+0.001);
# ewt_ex2_24=v_distispf(ewt_ex2_2+0.001,ewt_ex2_4+0.001);
# ewt_ex2_25=v_distispf(ewt_ex2_2+0.001,ewt_ex2_5+0.001);
# ewt_ex2_34=v_distispf(ewt_ex2_3+0.001,ewt_ex2_4+0.001);
# ewt_ex2_35=v_distispf(ewt_ex2_3+0.001,ewt_ex2_5+0.001);
# ewt_ex2_45=v_distispf(ewt_ex2_4+0.001,ewt_ex2_5+0.001);
#
# ewt_ex3 = readtable('C:\Ninapro\pieces_is\S8_C3_G3_T2_EWT.csv');
# ewt_ex3_1 = table2array(ewt_ex3(:,1)).';
# ewt_ex3_2 = table2array(ewt_ex3(:,2)).';
# ewt_ex3_3 = table2array(ewt_ex3(:,3)).';
# ewt_ex3_4 = table2array(ewt_ex3(:,4)).';
# ewt_ex3_5 = table2array(ewt_ex3(:,5)).';
# ewt_ex3_12=v_distispf(ewt_ex3_1+0.001,ewt_ex3_2+0.001);
# ewt_ex3_13=v_distispf(ewt_ex3_1+0.001,ewt_ex3_3+0.001);
# ewt_ex3_14=v_distispf(ewt_ex3_1+0.001,ewt_ex3_4+0.001);
# ewt_ex3_15=v_distispf(ewt_ex3_1+0.001,ewt_ex3_5+0.001);
# ewt_ex3_23=v_distispf(ewt_ex3_2+0.001,ewt_ex3_3+0.001);
# ewt_ex3_24=v_distispf(ewt_ex3_2+0.001,ewt_ex3_4+0.001);
# ewt_ex3_25=v_distispf(ewt_ex3_2+0.001,ewt_ex3_5+0.001);
# ewt_ex3_34=v_distispf(ewt_ex3_3+0.001,ewt_ex3_4+0.001);
# ewt_ex3_35=v_distispf(ewt_ex3_3+0.001,ewt_ex3_5+0.001);
# ewt_ex3_45=v_distispf(ewt_ex3_4+0.001,ewt_ex3_5+0.001);
#
#
# ewt_ex4 = readtable('C:\Ninapro\pieces_is\S4_C3_G7_T3_EWT.csv');
# ewt_ex4_1 = table2array(ewt_ex4(:,1)).';
# ewt_ex4_2 = table2array(ewt_ex4(:,2)).';
# ewt_ex4_3 = table2array(ewt_ex4(:,3)).';
# ewt_ex4_4 = table2array(ewt_ex4(:,4)).';
# ewt_ex4_5 = table2array(ewt_ex4(:,5)).';
# ewt_ex4_12=v_distispf(ewt_ex4_1+0.001,ewt_ex4_2+0.001);
# ewt_ex4_13=v_distispf(ewt_ex4_1+0.001,ewt_ex4_3+0.001);
# ewt_ex4_14=v_distispf(ewt_ex4_1+0.001,ewt_ex4_4+0.001);
# ewt_ex4_15=v_distispf(ewt_ex4_1+0.001,ewt_ex4_5+0.001);
# ewt_ex4_23=v_distispf(ewt_ex4_2+0.001,ewt_ex4_3+0.001);
# ewt_ex4_24=v_distispf(ewt_ex4_2+0.001,ewt_ex4_4+0.001);
# ewt_ex4_25=v_distispf(ewt_ex4_2+0.001,ewt_ex4_5+0.001);
# ewt_ex4_34=v_distispf(ewt_ex4_3+0.001,ewt_ex4_4+0.001);
# ewt_ex4_35=v_distispf(ewt_ex4_3+0.001,ewt_ex4_5+0.001);
# ewt_ex4_45=v_distispf(ewt_ex4_4+0.001,ewt_ex4_5+0.001);
#
#
# ewt_ex5 = readtable('C:\Ninapro\pieces_is\S3_C3_G5_T4_EWT.csv');
# ewt_ex5_1 = table2array(ewt_ex5(:,1)).';
# ewt_ex5_2 = table2array(ewt_ex5(:,2)).';
# ewt_ex5_3 = table2array(ewt_ex5(:,3)).';
# ewt_ex5_4 = table2array(ewt_ex5(:,4)).';
# ewt_ex5_5 = table2array(ewt_ex5(:,5)).';
# ewt_ex5_12=v_distispf(ewt_ex5_1+0.001,ewt_ex5_2+0.001);
# ewt_ex5_13=v_distispf(ewt_ex5_1+0.001,ewt_ex5_3+0.001);
# ewt_ex5_14=v_distispf(ewt_ex5_1+0.001,ewt_ex5_4+0.001);
# ewt_ex5_15=v_distispf(ewt_ex5_1+0.001,ewt_ex5_5+0.001);
# ewt_ex5_23=v_distispf(ewt_ex5_2+0.001,ewt_ex5_3+0.001);
# ewt_ex5_24=v_distispf(ewt_ex5_2+0.001,ewt_ex5_4+0.001);
# ewt_ex5_25=v_distispf(ewt_ex5_2+0.001,ewt_ex5_5+0.001);
# ewt_ex5_34=v_distispf(ewt_ex5_3+0.001,ewt_ex5_4+0.001);
# ewt_ex5_35=v_distispf(ewt_ex5_3+0.001,ewt_ex5_5+0.001);
# ewt_ex5_45=v_distispf(ewt_ex5_4+0.001,ewt_ex5_5+0.001);
#
#
# ewt_ex6 = readtable('C:\Ninapro\pieces_is\S10_C3_G16_T5_EWT.csv');
# ewt_ex6_1 = table2array(ewt_ex6(:,1)).';
# ewt_ex6_2 = table2array(ewt_ex6(:,2)).';
# ewt_ex6_3 = table2array(ewt_ex6(:,3)).';
# ewt_ex6_4 = table2array(ewt_ex6(:,4)).';
# ewt_ex6_5 = table2array(ewt_ex6(:,5)).';
# ewt_ex6_12=v_distispf(ewt_ex6_1+0.001,ewt_ex6_2+0.001);
# ewt_ex6_13=v_distispf(ewt_ex6_1+0.001,ewt_ex6_3+0.001);
# ewt_ex6_14=v_distispf(ewt_ex6_1+0.001,ewt_ex6_4+0.001);
# ewt_ex6_15=v_distispf(ewt_ex6_1+0.001,ewt_ex6_5+0.001);
# ewt_ex6_23=v_distispf(ewt_ex6_2+0.001,ewt_ex6_3+0.001);
# ewt_ex6_24=v_distispf(ewt_ex6_2+0.001,ewt_ex6_4+0.001);
# ewt_ex6_25=v_distispf(ewt_ex6_2+0.001,ewt_ex6_5+0.001);
# ewt_ex6_34=v_distispf(ewt_ex6_3+0.001,ewt_ex6_4+0.001);
# ewt_ex6_35=v_distispf(ewt_ex6_3+0.001,ewt_ex6_5+0.001);
# ewt_ex6_45=v_distispf(ewt_ex6_4+0.001,ewt_ex6_5+0.001);
#
#
# efd_ex1 = readtable('C:\Ninapro\pieces_is\S1_C3_G1_T3_EFD.csv');
# efd_ex1_1 = table2array(efd_ex1(:,1)).';
# efd_ex1_2 = table2array(efd_ex1(:,2)).';
# efd_ex1_3 = table2array(efd_ex1(:,3)).';
# efd_ex1_4 = table2array(efd_ex1(:,4)).';
# efd_ex1_5 = table2array(efd_ex1(:,5)).';
# efd_ex1_12=v_distispf(efd_ex1_1+0.001,efd_ex1_2+0.001);
# efd_ex1_13=v_distispf(efd_ex1_1+0.001,efd_ex1_3+0.001);
# efd_ex1_14=v_distispf(efd_ex1_1+0.001,efd_ex1_4+0.001);
# efd_ex1_15=v_distispf(efd_ex1_1+0.001,efd_ex1_5+0.001);
# efd_ex1_23=v_distispf(efd_ex1_2+0.001,efd_ex1_3+0.001);
# efd_ex1_24=v_distispf(efd_ex1_2+0.001,efd_ex1_4+0.001);
# efd_ex1_25=v_distispf(efd_ex1_2+0.001,efd_ex1_5+0.001);
# efd_ex1_34=v_distispf(efd_ex1_3+0.001,efd_ex1_4+0.001);
# efd_ex1_35=v_distispf(efd_ex1_3+0.001,efd_ex1_5+0.001);
# efd_ex1_45=v_distispf(efd_ex1_4+0.001,efd_ex1_5+0.001);
#
# efd_ex2 = readtable('C:\Ninapro\pieces_is\S6_C3_G10_T2_EFD.csv');
# efd_ex2_1 = table2array(efd_ex2(:,1)).';
# efd_ex2_2 = table2array(efd_ex2(:,2)).';
# efd_ex2_3 = table2array(efd_ex2(:,3)).';
# efd_ex2_4 = table2array(efd_ex2(:,4)).';
# efd_ex2_5 = table2array(efd_ex2(:,5)).';
# efd_ex2_12=v_distispf(efd_ex2_1+0.001,efd_ex2_2+0.001);
# efd_ex2_13=v_distispf(efd_ex2_1+0.001,efd_ex2_3+0.001);
# efd_ex2_14=v_distispf(efd_ex2_1+0.001,efd_ex2_4+0.001);
# efd_ex2_15=v_distispf(efd_ex2_1+0.001,efd_ex2_5+0.001);
# efd_ex2_23=v_distispf(efd_ex2_2+0.001,efd_ex2_3+0.001);
# efd_ex2_24=v_distispf(efd_ex2_2+0.001,efd_ex2_4+0.001);
# efd_ex2_25=v_distispf(efd_ex2_2+0.001,efd_ex2_5+0.001);
# efd_ex2_34=v_distispf(efd_ex2_3+0.001,efd_ex2_4+0.001);
# efd_ex2_35=v_distispf(efd_ex2_3+0.001,efd_ex2_5+0.001);
# efd_ex2_45=v_distispf(efd_ex2_4+0.001,efd_ex2_5+0.001);
#
# efd_ex3 = readtable('C:\Ninapro\pieces_is\S8_C3_G3_T2_EFD.csv');
# efd_ex3_1 = table2array(efd_ex3(:,1)).';
# efd_ex3_2 = table2array(efd_ex3(:,2)).';
# efd_ex3_3 = table2array(efd_ex3(:,3)).';
# efd_ex3_4 = table2array(efd_ex3(:,4)).';
# efd_ex3_5 = table2array(efd_ex3(:,5)).';
# efd_ex3_12=v_distispf(efd_ex3_1+0.001,efd_ex3_2+0.001);
# efd_ex3_13=v_distispf(efd_ex3_1+0.001,efd_ex3_3+0.001);
# efd_ex3_14=v_distispf(efd_ex3_1+0.001,efd_ex3_4+0.001);
# efd_ex3_15=v_distispf(efd_ex3_1+0.001,efd_ex3_5+0.001);
# efd_ex3_23=v_distispf(efd_ex3_2+0.001,efd_ex3_3+0.001);
# efd_ex3_24=v_distispf(efd_ex3_2+0.001,efd_ex3_4+0.001);
# efd_ex3_25=v_distispf(efd_ex3_2+0.001,efd_ex3_5+0.001);
# efd_ex3_34=v_distispf(efd_ex3_3+0.001,efd_ex3_4+0.001);
# efd_ex3_35=v_distispf(efd_ex3_3+0.001,efd_ex3_5+0.001);
# efd_ex3_45=v_distispf(efd_ex3_4+0.001,efd_ex3_5+0.001);
#
#
# efd_ex4 = readtable('C:\Ninapro\pieces_is\S4_C3_G7_T3_EFD.csv');
# efd_ex4_1 = table2array(efd_ex4(:,1)).';
# efd_ex4_2 = table2array(efd_ex4(:,2)).';
# efd_ex4_3 = table2array(efd_ex4(:,3)).';
# efd_ex4_4 = table2array(efd_ex4(:,4)).';
# efd_ex4_5 = table2array(efd_ex4(:,5)).';
# efd_ex4_12=v_distispf(efd_ex4_1+0.001,efd_ex4_2+0.001);
# efd_ex4_13=v_distispf(efd_ex4_1+0.001,efd_ex4_3+0.001);
# efd_ex4_14=v_distispf(efd_ex4_1+0.001,efd_ex4_4+0.001);
# efd_ex4_15=v_distispf(efd_ex4_1+0.001,efd_ex4_5+0.001);
# efd_ex4_23=v_distispf(efd_ex4_2+0.001,efd_ex4_3+0.001);
# efd_ex4_24=v_distispf(efd_ex4_2+0.001,efd_ex4_4+0.001);
# efd_ex4_25=v_distispf(efd_ex4_2+0.001,efd_ex4_5+0.001);
# efd_ex4_34=v_distispf(efd_ex4_3+0.001,efd_ex4_4+0.001);
# efd_ex4_35=v_distispf(efd_ex4_3+0.001,efd_ex4_5+0.001);
# efd_ex4_45=v_distispf(efd_ex4_4+0.001,efd_ex4_5+0.001);
#
#
# efd_ex5 = readtable('C:\Ninapro\pieces_is\S3_C3_G5_T4_EFD.csv');
# efd_ex5_1 = table2array(efd_ex5(:,1)).';
# efd_ex5_2 = table2array(efd_ex5(:,2)).';
# efd_ex5_3 = table2array(efd_ex5(:,3)).';
# efd_ex5_4 = table2array(efd_ex5(:,4)).';
# efd_ex5_5 = table2array(efd_ex5(:,5)).';
# efd_ex5_12=v_distispf(efd_ex5_1+0.001,efd_ex5_2+0.001);
# efd_ex5_13=v_distispf(efd_ex5_1+0.001,efd_ex5_3+0.001);
# efd_ex5_14=v_distispf(efd_ex5_1+0.001,efd_ex5_4+0.001);
# efd_ex5_15=v_distispf(efd_ex5_1+0.001,efd_ex5_5+0.001);
# efd_ex5_23=v_distispf(efd_ex5_2+0.001,efd_ex5_3+0.001);
# efd_ex5_24=v_distispf(efd_ex5_2+0.001,efd_ex5_4+0.001);
# efd_ex5_25=v_distispf(efd_ex5_2+0.001,efd_ex5_5+0.001);
# efd_ex5_34=v_distispf(efd_ex5_3+0.001,efd_ex5_4+0.001);
# efd_ex5_35=v_distispf(efd_ex5_3+0.001,efd_ex5_5+0.001);
# efd_ex5_45=v_distispf(efd_ex5_4+0.001,efd_ex5_5+0.001);
#
#
# efd_ex6 = readtable('C:\Ninapro\pieces_is\S10_C3_G16_T5_EFD.csv');
# efd_ex6_1 = table2array(efd_ex6(:,1)).';
# efd_ex6_2 = table2array(efd_ex6(:,2)).';
# efd_ex6_3 = table2array(efd_ex6(:,3)).';
# efd_ex6_4 = table2array(efd_ex6(:,4)).';
# efd_ex6_5 = table2array(efd_ex6(:,5)).';
# efd_ex6_12=v_distispf(efd_ex6_1+0.001,efd_ex6_2+0.001);
# efd_ex6_13=v_distispf(efd_ex6_1+0.001,efd_ex6_3+0.001);
# efd_ex6_14=v_distispf(efd_ex6_1+0.001,efd_ex6_4+0.001);
# efd_ex6_15=v_distispf(efd_ex6_1+0.001,efd_ex6_5+0.001);
# efd_ex6_23=v_distispf(efd_ex6_2+0.001,efd_ex6_3+0.001);
# efd_ex6_24=v_distispf(efd_ex6_2+0.001,efd_ex6_4+0.001);
# efd_ex6_25=v_distispf(efd_ex6_2+0.001,efd_ex6_5+0.001);
# efd_ex6_34=v_distispf(efd_ex6_3+0.001,efd_ex6_4+0.001);
# efd_ex6_35=v_distispf(efd_ex6_3+0.001,efd_ex6_5+0.001);
# efd_ex6_45=v_distispf(efd_ex6_4+0.001,efd_ex6_5+0.001);

# %% [markdown]
# ## 7.  Save all the distances from Section 6 in dataframe
# After converting from .mat to .csv, some manipulation was done in excel.

# %%
from scipy.io import loadmat
import pandas as pd
mat = loadmat(r'C:\Users\16468\Desktop\Pancholi\matlab_is_dist_2.mat')
#mat to csv
resultList = list(mat.keys())
vals = list(mat.values())
df = pd.DataFrame({'name':resultList,'value':vals})
df.to_csv(r'C:\Users\16468\Desktop\Pancholi\matlab_is_dist_2.csv')

# %%
df_fin_2=pd.read_csv(r'C:\Users\16468\Desktop\Pancholi\matlab_is_distance_2.csv')

# %%
df_fin_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     120 non-null    object
#  1   method   120 non-null    object
#  2   example  120 non-null    object
#  3   2_comp   120 non-null    object
#  4   value    120 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 4.8+ KB

# %%
convert_dict = {'2_comp': str}
 
df_fin_2 = df_fin_2.astype(convert_dict)

# %% [markdown]
# ## 8. Line plot for gestures

# %%
# separate each example signal
df_ex1= df_fin_2[df_fin_2['example']=='ex1']
df_ex2= df_fin_2[df_fin_2['example']=='ex2']
df_ex3= df_fin_2[df_fin_2['example']=='ex3']
df_ex4= df_fin_2[df_fin_2['example']=='ex4']
df_ex5= df_fin_2[df_fin_2['example']=='ex5']
df_ex6= df_fin_2[df_fin_2['example']=='ex6']

# %%
figure(figsize=(10,5))
y1=df_ex1[df_ex1['method']=='ewt']['value']
y2=df_ex2[df_ex2['method']=='ewt']['value']
y3=df_ex3[df_ex3['method']=='ewt']['value']
y4=df_ex4[df_ex4['method']=='ewt']['value']
y5=df_ex5[df_ex5['method']=='ewt']['value']
y6=df_ex6[df_ex6['method']=='ewt']['value']

x1=df_ex1[df_ex1['method']=='ewt']['2_comp']
x2=df_ex2[df_ex2['method']=='ewt']['2_comp']
x3=df_ex3[df_ex3['method']=='ewt']['2_comp']
x4=df_ex4[df_ex4['method']=='ewt']['2_comp']
x5=df_ex5[df_ex5['method']=='ewt']['2_comp']
x6=df_ex6[df_ex6['method']=='ewt']['2_comp']

l1=plt.plot(x1,y1,'ro--',label='G1')
l2=plt.plot(x2,y2,'go--',label='G10')
l3=plt.plot(x3,y3,'bo--',label='G3')
l4=plt.plot(x4,y4,'co--',label='G7')
l5=plt.plot(x5,y5,'mo--',label='G5')
l6=plt.plot(x6,y6,'yo--',label='G16')

plt.title('The IS-Distance between each components with 6 gestures (EWT)')
plt.xlabel('Component pairs')
plt.ylabel('IS-Distances')
plt.legend()
plt.plot()
# Out:
# []

# %%
figure(figsize=(10,5))
y1=df_ex1[df_ex1['method']=='efd']['value']
y2=df_ex2[df_ex2['method']=='efd']['value']
y3=df_ex3[df_ex3['method']=='efd']['value']
y4=df_ex4[df_ex4['method']=='efd']['value']
y5=df_ex5[df_ex5['method']=='efd']['value']
y6=df_ex6[df_ex6['method']=='efd']['value']

x1=df_ex1[df_ex1['method']=='efd']['2_comp']
x2=df_ex2[df_ex2['method']=='efd']['2_comp']
x3=df_ex3[df_ex3['method']=='efd']['2_comp']
x4=df_ex4[df_ex4['method']=='efd']['2_comp']
x5=df_ex5[df_ex5['method']=='efd']['2_comp']
x6=df_ex6[df_ex6['method']=='efd']['2_comp']

l1=plt.plot(x1,y1,'ro--',label='G1')
l2=plt.plot(x2,y2,'go--',label='G10')
l3=plt.plot(x3,y3,'bo--',label='G3')
l4=plt.plot(x4,y4,'co--',label='G7')
l5=plt.plot(x5,y5,'mo--',label='G5')
l6=plt.plot(x6,y6,'yo--',label='G16')

plt.title('The IS-Distance between each components with 6 gestures (EFD)')
plt.xlabel('Component pairs')
plt.ylabel('IS-Distances')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# ### Put 12 lines together

# %%
figure(figsize=(20,10))
y1=df_ex1[df_ex1['method']=='ewt']['value']
y2=df_ex2[df_ex2['method']=='ewt']['value']
y3=df_ex3[df_ex3['method']=='ewt']['value']
y4=df_ex4[df_ex4['method']=='ewt']['value']
y5=df_ex5[df_ex5['method']=='ewt']['value']
y6=df_ex6[df_ex6['method']=='ewt']['value']

x1=df_ex1[df_ex1['method']=='ewt']['2_comp']
x2=df_ex2[df_ex2['method']=='ewt']['2_comp']
x3=df_ex3[df_ex3['method']=='ewt']['2_comp']
x4=df_ex4[df_ex4['method']=='ewt']['2_comp']
x5=df_ex5[df_ex5['method']=='ewt']['2_comp']
x6=df_ex6[df_ex6['method']=='ewt']['2_comp']

y_1=df_ex1[df_ex1['method']=='efd']['value']
y_2=df_ex2[df_ex2['method']=='efd']['value']
y_3=df_ex3[df_ex3['method']=='efd']['value']
y_4=df_ex4[df_ex4['method']=='efd']['value']
y_5=df_ex5[df_ex5['method']=='efd']['value']
y_6=df_ex6[df_ex6['method']=='efd']['value']

l1=plt.plot(x1,y1,'ro--',label='G1_EWT')
l2=plt.plot(x2,y2,'go--',label='G10_EWT')
l3=plt.plot(x3,y3,'bo--',label='G3_EWT')
l4=plt.plot(x4,y4,'co--',label='G7_EWT')
l5=plt.plot(x5,y5,'mo--',label='G5_EWT')
l6=plt.plot(x6,y6,'yo--',label='G16_EWT')

ll1=plt.plot(x1,y_1,'rs--',label='G1_EFD')
ll2=plt.plot(x2,y_2,'gs--',label='G10_EFD')
ll3=plt.plot(x3,y_3,'bs--',label='G3_EFD')
ll4=plt.plot(x4,y_4,'cs--',label='G7_EFD')
ll5=plt.plot(x5,y_5,'ms--',label='G5_EFD')
ll6=plt.plot(x6,y_6,'ys--',label='G16_EFD')

plt.title('The IS-Distance between each components with 6 gestures (EWT&EFD)')
plt.xlabel('Component pairs')
plt.ylabel('IS-Distances')
plt.legend()
plt.plot()
# Out:
# []
